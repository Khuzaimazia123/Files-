# %%
File = open("diary.txt", "w")
File.write("Today I ate fruits and drank water")
File.close()

File = open("diary.txt", "r")
content = File.read()
print(content)
File.close()

with open("notes.txt", "w") as file:
 print (file.write("Give me a small toy"))

try :
 file = open("not.txt", "r")
 print (file.read())
 file.close()
except FileNotFoundError :
 print (f"Oops, well it looks like you forgot to make this file")

file = open("diary.txt", "w")
file.write("Today I went to superstore and got apples")
file.close()
# Out:
# Today I ate fruits and drank water
# 19
# Oops, well it looks like you forgot to make this file
